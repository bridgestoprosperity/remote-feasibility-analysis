# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/all_sites_09032026.csv")
df.info()

# %%
df.head()

# %%
has_coords = df[~df["GPS (Latitude)"].isna() & ~df["GPS (Longitude)"].isna()].copy()

# %%
has_coords.shape

# %%
has_coords["Sub-Stage"].value_counts(dropna=False)

# %%
has_coords["Stage"].value_counts()
